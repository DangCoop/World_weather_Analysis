# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
#Create a list with latitudes and longitudes.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Create a list for holding the cities.
cities = []
#Identify the nearest city 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
   #Create a cities list
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 746

# %%
#Import requests library.
import requests

#Import the API Key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Descritpion": city_description})                         

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 1 | faanui
# Processing Record 3 of Set 1 | plouzane
# Processing Record 4 of Set 1 | deniliquin
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | bay-khaak
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | naustdal
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | saint anthony
# Processing Record 11 of Set 1 | samarai
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | foindu
# Processing Record 15 of Set 1 | dospat
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | lata
# Processing Record 18 of Set 1 | nanortalik
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | kargasok
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | kitgum
# Processing Record 26 of Set 1 | natchez
# Processing Record 27 of Set 1 | isangel
# Processing Record 28 of Set 1 | reporoa
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | carnarvon
# Processing Record 31 of Set 1 | san lawrenz
# Processing Record 32 of Set 1 | madera
# Processing Record 33 of Set 1 | esperance
# Processing Record 34 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 1 | visby
# Processing Record 36 of Set 1 | jardim
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | north bend
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | luderitz
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | jamkhandi
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 47 of Set 1 | portland
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | maryborough
# Processing Record 3 of Set 2 | aquiraz
# Processing Record 4 of Set 2 | vostok
# Processing Record 5 of Set 2 | fortuna
# Processing Record 6 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | darhan
# Processing Record 10 of Set 2 | alpena
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | lac du bonnet
# Processing Record 16 of Set 2 | muros
# Processing Record 17 of Set 2 | mount isa
# Processing Record 18 of Set 2 | mar del plata
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | raton
# Processing Record 22 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | fort nelson
# Processing Record 26 of Set 2 | katsuura
# Processing Record 27 of Set 2 | ust-nera
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | coihaique
# Processing Record 30 of Set 2 | windhoek
# Processing Record 31 of Set 2 | rosetta
# Processing Record 32 of Set 2 | broome
# Processing Record 33 of Set 2 | aksu
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | sur
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | ostrovnoy
# Processing Record 40 of Set 2 | bestobe
# Processing Record 41 of Set 2 | elko
# Processing Record 42 of Set 2 | tessalit
# Processing Record 43 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 2 | panalingaan
# Processing Record 47 of Set 2 | jalu
# Processing Record 48 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 49 of Set 2 | pangody
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | maridi
# Processing Record 2 of Set 3 | araouane
# Processing Record 3 of Set 3 | alofi
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | naze
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | narsaq
# Processing Record 8 of Set 3 | pisco
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | delogozdi
# City not found. Skipping...
# Processing Record 11 of Set 3 | mataura
# Processing Record 12 of Set 3 | hanstholm
# Processing Record 13 of Set 3 | linjiang
# Processing Record 14 of Set 3 | richards bay
# Processing Record 15 of Set 3 | antofagasta
# Processing Record 16 of Set 3 | ronse
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | touros
# Processing Record 19 of Set 3 | cururupu
# Processing Record 20 of Set 3 | campobasso
# Processing Record 21 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | morehead
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | pevek
# Processing Record 26 of Set 3 | rudnogorsk
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | gamba
# Processing Record 29 of Set 3 | umm lajj
# Processing Record 30 of Set 3 | longyearbyen
# Processing Record 31 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 3 | camacha
# Processing Record 33 of Set 3 | maldonado
# Processing Record 34 of Set 3 | gat
# Processing Record 35 of Set 3 | havre
# Processing Record 36 of Set 3 | culebra
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | faya
# Processing Record 40 of Set 3 | san policarpo
# Processing Record 41 of Set 3 | ishigaki
# Processing Record 42 of Set 3 | qaqortoq
# Processing Record 43 of Set 3 | bustamante
# Processing Record 44 of Set 3 | ponta do sol
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 3 | nouadhibou
# Processing Record 48 of Set 3 | kahului
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | bitung
# Processing Record 1 of Set 4 | puerto carreno
# Processing Record 2 of Set 4 | gornopravdinsk
# Processing Record 3 of Set 4 | mount gambier
# Processing Record 4 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 4 | kuliyapitiya
# Processing Record 6 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 7 of Set 4 | palu
# Processing Record 8 of Set 4 | kaduna
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | quatre cocos
# Processing Record 12 of Set 4 | lagoa
# Processing Record 13 of Set 4 | tongliao
# Processing Record 14 of Set 4 | wareham
# Processing Record 15 of Set 4 | caidian
# Processing Record 16 of Set 4 | flinders
# Processing Record 17 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 4 | hasaki
# Processing Record 19 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 4 | jamame
# Processing Record 21 of Set 4 | ngunguru
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | sorokino
# Processing Record 24 of Set 4 | gorele
# Processing Record 25 of Set 4 | olafsvik
# Processing Record 26 of Set 4 | manali
# Processing Record 27 of Set 4 | westport
# Processing Record 28 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 4 | husavik
# Processing Record 30 of Set 4 | panaba
# Processing Record 31 of Set 4 | carutapera
# Processing Record 32 of Set 4 | algiers
# Processing Record 33 of Set 4 | buin
# Processing Record 34 of Set 4 | vestmannaeyjar
# Processing Record 35 of Set 4 | melfi
# Processing Record 36 of Set 4 | waipawa
# Processing Record 37 of Set 4 | olinda
# Processing Record 38 of Set 4 | korla
# Processing Record 39 of Set 4 | pangnirtung
# Processing Record 40 of Set 4 | miles city
# Processing Record 41 of Set 4 | hualmay
# Processing Record 42 of Set 4 | evensk
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | san miguel
# Processing Record 45 of Set 4 | maragogi
# Processing Record 46 of Set 4 | aklavik
# Processing Record 47 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | abalak
# Processing Record 50 of Set 4 | tuktoyaktuk
# Processing Record 1 of Set 5 | smirnykh
# Processing Record 2 of Set 5 | virginia beach
# Processing Record 3 of Set 5 | sabzevar
# Processing Record 4 of Set 5 | mahon
# Processing Record 5 of Set 5 | ilulissat
# Processing Record 6 of Set 5 | nagato
# Processing Record 7 of Set 5 | la asuncion
# Processing Record 8 of Set 5 | bathsheba
# Processing Record 9 of Set 5 | taltal
# Processing Record 10 of Set 5 | zhicheng
# Processing Record 11 of Set 5 | tuatapere
# Processing Record 12 of Set 5 | caravelas
# Processing Record 13 of Set 5 | usinsk
# Processing Record 14 of Set 5 | salalah
# Processing Record 15 of Set 5 | japura
# Processing Record 16 of Set 5 | amapa
# Processing Record 17 of Set 5 | hit
# Processing Record 18 of Set 5 | namie
# Processing Record 19 of Set 5 | amga
# Processing Record 20 of Set 5 | lorengau
# Processing Record 21 of Set 5 | troy
# Processing Record 22 of Set 5 | alabaster
# Processing Record 23 of Set 5 | lyuban
# Processing Record 24 of Set 5 | alamogordo
# Processing Record 25 of Set 5 | wadi musa
# Processing Record 26 of Set 5 | huai mek
# Processing Record 27 of Set 5 | yerbogachen
# Processing Record 28 of Set 5 | garissa
# Processing Record 29 of Set 5 | maxixe
# Processing Record 30 of Set 5 | wakkanai
# Processing Record 31 of Set 5 | salinas
# Processing Record 32 of Set 5 | young
# Processing Record 33 of Set 5 | grindavik
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | zhoucheng
# Processing Record 36 of Set 5 | loharu
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | berlevag
# Processing Record 39 of Set 5 | sorong
# Processing Record 40 of Set 5 | victoria
# Processing Record 41 of Set 5 | kropotkin
# Processing Record 42 of Set 5 | tamiahua
# Processing Record 43 of Set 5 | chuy
# Processing Record 44 of Set 5 | bay roberts
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | tamsweg
# Processing Record 47 of Set 5 | nara
# Processing Record 48 of Set 5 | kaeo
# Processing Record 49 of Set 5 | shingu
# Processing Record 50 of Set 5 | inhambane
# Processing Record 1 of Set 6 | taoudenni
# Processing Record 2 of Set 6 | ballina
# Processing Record 3 of Set 6 | kitimat
# Processing Record 4 of Set 6 | miyako
# Processing Record 5 of Set 6 | nanakuli
# Processing Record 6 of Set 6 | dicabisagan
# Processing Record 7 of Set 6 | chenghai
# Processing Record 8 of Set 6 | moyale
# Processing Record 9 of Set 6 | kununurra
# Processing Record 10 of Set 6 | mangrol
# Processing Record 11 of Set 6 | xiongzhou
# Processing Record 12 of Set 6 | pervomayskoye
# Processing Record 13 of Set 6 | sioux lookout
# Processing Record 14 of Set 6 | nikolskoye
# Processing Record 15 of Set 6 | may pen
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | gallup
# Processing Record 18 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 6 | linshu
# City not found. Skipping...
# Processing Record 20 of Set 6 | klaebu
# Processing Record 21 of Set 6 | kankon
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | oktyabrskiy
# Processing Record 24 of Set 6 | los llanos de aridane
# Processing Record 25 of Set 6 | yumen
# Processing Record 26 of Set 6 | marshall
# Processing Record 27 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 6 | kirakira
# Processing Record 29 of Set 6 | merauke
# Processing Record 30 of Set 6 | shelburne
# Processing Record 31 of Set 6 | sibolga
# Processing Record 32 of Set 6 | zhangye
# Processing Record 33 of Set 6 | vardo
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | dahod
# Processing Record 36 of Set 6 | hoa binh
# Processing Record 37 of Set 6 | taraz
# Processing Record 38 of Set 6 | pryamitsyno
# Processing Record 39 of Set 6 | cockburn town
# Processing Record 40 of Set 6 | erzin
# Processing Record 41 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 6 | sabla
# Processing Record 43 of Set 6 | kapiri mposhi
# Processing Record 44 of Set 6 | nome
# Processing Record 45 of Set 6 | kurilsk
# Processing Record 46 of Set 6 | killybegs
# Processing Record 47 of Set 6 | yeppoon
# Processing Record 48 of Set 6 | yanam
# Processing Record 49 of Set 6 | klaksvik
# Processing Record 50 of Set 6 | aksay
# Processing Record 1 of Set 7 | mandalgovi
# Processing Record 2 of Set 7 | hamilton
# Processing Record 3 of Set 7 | dejen
# Processing Record 4 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 7 | dunedin
# Processing Record 6 of Set 7 | bilma
# Processing Record 7 of Set 7 | hopeman
# Processing Record 8 of Set 7 | chicama
# Processing Record 9 of Set 7 | egvekinot
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | kruisfontein
# Processing Record 12 of Set 7 | cabedelo
# Processing Record 13 of Set 7 | sabha
# Processing Record 14 of Set 7 | san jose
# Processing Record 15 of Set 7 | trecate
# Processing Record 16 of Set 7 | la rioja
# Processing Record 17 of Set 7 | bolivar
# Processing Record 18 of Set 7 | blackwater
# Processing Record 19 of Set 7 | calvia
# Processing Record 20 of Set 7 | iqaluit
# Processing Record 21 of Set 7 | rajgarh
# Processing Record 22 of Set 7 | katherine
# Processing Record 23 of Set 7 | beipiao
# Processing Record 24 of Set 7 | nicolas bravo
# Processing Record 25 of Set 7 | macultepec
# Processing Record 26 of Set 7 | tsiroanomandidy
# Processing Record 27 of Set 7 | poum
# Processing Record 28 of Set 7 | bengkulu
# Processing Record 29 of Set 7 | coquimbo
# Processing Record 30 of Set 7 | sapele
# Processing Record 31 of Set 7 | winnemucca
# Processing Record 32 of Set 7 | suraabad
# Processing Record 33 of Set 7 | mazatlan
# Processing Record 34 of Set 7 | kavieng
# Processing Record 35 of Set 7 | kattivakkam
# Processing Record 36 of Set 7 | hutchinson
# Processing Record 37 of Set 7 | puerto leguizamo
# Processing Record 38 of Set 7 | romans-sur-isere
# Processing Record 39 of Set 7 | yulara
# Processing Record 40 of Set 7 | mujiayingzi
# Processing Record 41 of Set 7 | rawson
# Processing Record 42 of Set 7 | miandoab
# Processing Record 43 of Set 7 | chardara
# Processing Record 44 of Set 7 | turbat
# Processing Record 45 of Set 7 | am timan
# Processing Record 46 of Set 7 | dikson
# Processing Record 47 of Set 7 | san felipe
# Processing Record 48 of Set 7 | chikoy
# City not found. Skipping...
# Processing Record 49 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 7 | kasongo-lunda
# Processing Record 1 of Set 8 | santa cruz de tenerife
# Processing Record 2 of Set 8 | puerto madryn
# Processing Record 3 of Set 8 | skibbereen
# Processing Record 4 of Set 8 | beloha
# Processing Record 5 of Set 8 | begichevskiy
# Processing Record 6 of Set 8 | janauba
# Processing Record 7 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 8 | honningsvag
# Processing Record 9 of Set 8 | mecca
# Processing Record 10 of Set 8 | jacareacanga
# Processing Record 11 of Set 8 | vila franca do campo
# Processing Record 12 of Set 8 | poronaysk
# Processing Record 13 of Set 8 | noumea
# Processing Record 14 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 8 | pareora
# Processing Record 16 of Set 8 | rudbar
# Processing Record 17 of Set 8 | prince rupert
# Processing Record 18 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 8 | bouillante
# Processing Record 20 of Set 8 | moussoro
# Processing Record 21 of Set 8 | novi pazar
# Processing Record 22 of Set 8 | margate
# Processing Record 23 of Set 8 | laguna
# Processing Record 24 of Set 8 | oron
# Processing Record 25 of Set 8 | dingle
# Processing Record 26 of Set 8 | bandarbeyla
# Processing Record 27 of Set 8 | ketchikan
# Processing Record 28 of Set 8 | carahue
# Processing Record 29 of Set 8 | terney
# Processing Record 30 of Set 8 | ixtapa
# Processing Record 31 of Set 8 | adelaide
# Processing Record 32 of Set 8 | karasburg
# Processing Record 33 of Set 8 | college
# Processing Record 34 of Set 8 | ordzhonikidze
# Processing Record 35 of Set 8 | mikhaylovka
# Processing Record 36 of Set 8 | tiksi
# Processing Record 37 of Set 8 | petropavlovka
# Processing Record 38 of Set 8 | graham
# Processing Record 39 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 40 of Set 8 | pangai
# Processing Record 41 of Set 8 | tete
# Processing Record 42 of Set 8 | san cristobal
# Processing Record 43 of Set 8 | roald
# Processing Record 44 of Set 8 | diapaga
# Processing Record 45 of Set 8 | coffeyville
# Processing Record 46 of Set 8 | port macquarie
# Processing Record 47 of Set 8 | thinadhoo
# Processing Record 48 of Set 8 | moron
# Processing Record 49 of Set 8 | verbilki
# Processing Record 50 of Set 8 | xiaoweizhai
# Processing Record 1 of Set 9 | west wendover
# Processing Record 2 of Set 9 | auki
# Processing Record 3 of Set 9 | cabo san lucas
# Processing Record 4 of Set 9 | peterhead
# Processing Record 5 of Set 9 | traverse city
# Processing Record 6 of Set 9 | ahipara
# Processing Record 7 of Set 9 | chokwe
# Processing Record 8 of Set 9 | consett
# Processing Record 9 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 9 | malindi
# Processing Record 11 of Set 9 | port shepstone
# Processing Record 12 of Set 9 | flagstaff
# Processing Record 13 of Set 9 | san quintin
# Processing Record 14 of Set 9 | mildura
# Processing Record 15 of Set 9 | guilin
# Processing Record 16 of Set 9 | plettenberg bay
# Processing Record 17 of Set 9 | puerto del rosario
# Processing Record 18 of Set 9 | komsomolskiy
# Processing Record 19 of Set 9 | shache
# Processing Record 20 of Set 9 | souillac
# Processing Record 21 of Set 9 | peleduy
# Processing Record 22 of Set 9 | rutland
# Processing Record 23 of Set 9 | yaan
# Processing Record 24 of Set 9 | huambo
# Processing Record 25 of Set 9 | mizan teferi
# Processing Record 26 of Set 9 | tysmenytsya
# Processing Record 27 of Set 9 | kavaratti
# Processing Record 28 of Set 9 | sisimiut
# Processing Record 29 of Set 9 | shenzhen
# Processing Record 30 of Set 9 | quesnel
# Processing Record 31 of Set 9 | halifax
# Processing Record 32 of Set 9 | leningradskiy
# Processing Record 33 of Set 9 | sakakah
# Processing Record 34 of Set 9 | brokopondo
# Processing Record 35 of Set 9 | churapcha
# Processing Record 36 of Set 9 | port keats
# Processing Record 37 of Set 9 | kodinsk
# Processing Record 38 of Set 9 | boshnyakovo
# Processing Record 39 of Set 9 | atar
# Processing Record 40 of Set 9 | saint-pierre
# Processing Record 41 of Set 9 | cherskiy
# Processing Record 42 of Set 9 | mumbwa
# Processing Record 43 of Set 9 | luanda
# Processing Record 44 of Set 9 | butembo
# Processing Record 45 of Set 9 | acajutla
# Processing Record 46 of Set 9 | bubaque
# Processing Record 47 of Set 9 | akyab
# Processing Record 48 of Set 9 | xining
# Processing Record 49 of Set 9 | pedernales
# Processing Record 50 of Set 9 | regina
# Processing Record 1 of Set 10 | hovd
# Processing Record 2 of Set 10 | chandvad
# Processing Record 3 of Set 10 | marondera
# Processing Record 4 of Set 10 | vila velha
# Processing Record 5 of Set 10 | raudeberg
# Processing Record 6 of Set 10 | watertown
# Processing Record 7 of Set 10 | matara
# Processing Record 8 of Set 10 | zaragoza
# Processing Record 9 of Set 10 | vestmanna
# Processing Record 10 of Set 10 | baykit
# Processing Record 11 of Set 10 | antanifotsy
# Processing Record 12 of Set 10 | liaocheng
# Processing Record 13 of Set 10 | ancud
# Processing Record 14 of Set 10 | manitouwadge
# Processing Record 15 of Set 10 | darab
# Processing Record 16 of Set 10 | lianzhou
# Processing Record 17 of Set 10 | biryusinsk
# Processing Record 18 of Set 10 | hambantota
# Processing Record 19 of Set 10 | a
# City not found. Skipping...
# Processing Record 20 of Set 10 | howard springs
# Processing Record 21 of Set 10 | alamosa
# Processing Record 22 of Set 10 | strezhevoy
# Processing Record 23 of Set 10 | kisangani
# Processing Record 24 of Set 10 | houma
# Processing Record 25 of Set 10 | ouro preto do oeste
# Processing Record 26 of Set 10 | arcata
# Processing Record 27 of Set 10 | minbu
# Processing Record 28 of Set 10 | hay river
# Processing Record 29 of Set 10 | rawlins
# Processing Record 30 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 10 | pacific grove
# Processing Record 32 of Set 10 | puerto escondido
# Processing Record 33 of Set 10 | yar-sale
# Processing Record 34 of Set 10 | oskemen
# Processing Record 35 of Set 10 | kamaishi
# Processing Record 36 of Set 10 | tarbes
# Processing Record 37 of Set 10 | gimli
# Processing Record 38 of Set 10 | yabrud
# Processing Record 39 of Set 10 | makakilo city
# Processing Record 40 of Set 10 | camargo
# Processing Record 41 of Set 10 | leninsk
# Processing Record 42 of Set 10 | ayan
# Processing Record 43 of Set 10 | mahebourg
# Processing Record 44 of Set 10 | saint-andre-les-vergers
# Processing Record 45 of Set 10 | cilegon
# Processing Record 46 of Set 10 | ziarat
# Processing Record 47 of Set 10 | cao bang
# Processing Record 48 of Set 10 | chake chake
# Processing Record 49 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 10 | whitianga
# Processing Record 1 of Set 11 | port-gentil
# Processing Record 2 of Set 11 | jos
# Processing Record 3 of Set 11 | honiara
# Processing Record 4 of Set 11 | sola
# Processing Record 5 of Set 11 | port hardy
# Processing Record 6 of Set 11 | bolu
# Processing Record 7 of Set 11 | koboko
# Processing Record 8 of Set 11 | axim
# Processing Record 9 of Set 11 | guerrero negro
# Processing Record 10 of Set 11 | panzhihua
# Processing Record 11 of Set 11 | marand
# Processing Record 12 of Set 11 | sobolevo
# Processing Record 13 of Set 11 | yelizovo
# Processing Record 14 of Set 11 | rocha
# Processing Record 15 of Set 11 | fairbanks
# Processing Record 16 of Set 11 | upernavik
# Processing Record 17 of Set 11 | forbes
# Processing Record 18 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 19 of Set 11 | kuteynykove
# Processing Record 20 of Set 11 | ternate
# Processing Record 21 of Set 11 | sao joao da barra
# Processing Record 22 of Set 11 | san rafael
# Processing Record 23 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 11 | jinchang
# Processing Record 25 of Set 11 | parana
# Processing Record 26 of Set 11 | santa rita
# Processing Record 27 of Set 11 | najran
# Processing Record 28 of Set 11 | moba
# Processing Record 29 of Set 11 | puri
# Processing Record 30 of Set 11 | nehe
# Processing Record 31 of Set 11 | praia da vitoria
# Processing Record 32 of Set 11 | pochutla
# Processing Record 33 of Set 11 | tlaxiaco
# City not found. Skipping...
# Processing Record 34 of Set 11 | coos bay
# Processing Record 35 of Set 11 | vallenar
# Processing Record 36 of Set 11 | hailey
# Processing Record 37 of Set 11 | bismarck
# Processing Record 38 of Set 11 | regidor
# Processing Record 39 of Set 11 | redcar
# Processing Record 40 of Set 11 | san jeronimo
# Processing Record 41 of Set 11 | road town
# Processing Record 42 of Set 11 | ensley
# Processing Record 43 of Set 11 | pyapon
# Processing Record 44 of Set 11 | filadelfia
# Processing Record 45 of Set 11 | koudougou
# Processing Record 46 of Set 11 | mastung
# Processing Record 47 of Set 11 | tugulym
# Processing Record 48 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 11 | machiques
# Processing Record 50 of Set 11 | shirokiy
# Processing Record 1 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 12 | tura
# Processing Record 3 of Set 12 | puerto baquerizo moreno
# Processing Record 4 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 5 of Set 12 | severo-kurilsk
# Processing Record 6 of Set 12 | marfino
# Processing Record 7 of Set 12 | ibra
# Processing Record 8 of Set 12 | ilo
# Processing Record 9 of Set 12 | pictou
# Processing Record 10 of Set 12 | ottawa
# Processing Record 11 of Set 12 | tual
# Processing Record 12 of Set 12 | deyang
# Processing Record 13 of Set 12 | xihe
# Processing Record 14 of Set 12 | talas
# Processing Record 15 of Set 12 | talnakh
# Processing Record 16 of Set 12 | tiznit
# Processing Record 17 of Set 12 | gwadar
# Processing Record 18 of Set 12 | wanning
# Processing Record 19 of Set 12 | maumere
# Processing Record 20 of Set 12 | rayadrug
# Processing Record 21 of Set 12 | labuhan
# Processing Record 22 of Set 12 | sitka
# Processing Record 23 of Set 12 | springfield
# Processing Record 24 of Set 12 | lasa
# Processing Record 25 of Set 12 | presidencia roque saenz pena
# Processing Record 26 of Set 12 | fort saint james
# Processing Record 27 of Set 12 | vuktyl
# Processing Record 28 of Set 12 | kampene
# Processing Record 29 of Set 12 | itarema
# Processing Record 30 of Set 12 | payo
# Processing Record 31 of Set 12 | tungor
# Processing Record 32 of Set 12 | illapel
# Processing Record 33 of Set 12 | marawi
# Processing Record 34 of Set 12 | sandwick
# Processing Record 35 of Set 12 | novopokrovka
# Processing Record 36 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 12 | piacabucu
# Processing Record 38 of Set 12 | bamako
# Processing Record 39 of Set 12 | karur
# Processing Record 40 of Set 12 | haines junction
# Processing Record 41 of Set 12 | karasjok
# Processing Record 42 of Set 12 | dwarka
# Processing Record 43 of Set 12 | biak
# Processing Record 44 of Set 12 | ara
# Processing Record 45 of Set 12 | kloulklubed
# Processing Record 46 of Set 12 | dharmanagar
# Processing Record 47 of Set 12 | lazaro cardenas
# Processing Record 48 of Set 12 | kidal
# Processing Record 49 of Set 12 | te anau
# Processing Record 50 of Set 12 | gornyak
# Processing Record 1 of Set 13 | phan thiet
# Processing Record 2 of Set 13 | morro bay
# Processing Record 3 of Set 13 | saint monans
# Processing Record 4 of Set 13 | codrington
# Processing Record 5 of Set 13 | khash
# Processing Record 6 of Set 13 | ulaangom
# Processing Record 7 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 13 | alihe
# Processing Record 9 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 13 | vao
# Processing Record 11 of Set 13 | lima
# Processing Record 12 of Set 13 | maykor
# Processing Record 13 of Set 13 | madang
# Processing Record 14 of Set 13 | pyu
# Processing Record 15 of Set 13 | cordoba
# Processing Record 16 of Set 13 | rancho palos verdes
# Processing Record 17 of Set 13 | petatlan
# Processing Record 18 of Set 13 | fereydun kenar
# Processing Record 19 of Set 13 | ondo
# Processing Record 20 of Set 13 | bloomington
# Processing Record 21 of Set 13 | jawhar
# Processing Record 22 of Set 13 | rabo de peixe
# Processing Record 23 of Set 13 | flin flon
# Processing Record 24 of Set 13 | xinmin
# Processing Record 25 of Set 13 | manica
# Processing Record 26 of Set 13 | nyagan
# Processing Record 27 of Set 13 | krasnoselkup
# Processing Record 28 of Set 13 | englewood
# Processing Record 29 of Set 13 | borogontsy
# Processing Record 30 of Set 13 | tadine
# Processing Record 31 of Set 13 | tournai
# Processing Record 32 of Set 13 | tilichiki
# Processing Record 33 of Set 13 | mier
# Processing Record 34 of Set 13 | rock springs
# Processing Record 35 of Set 13 | thunder bay
# Processing Record 36 of Set 13 | san buenaventura
# Processing Record 37 of Set 13 | juntas
# Processing Record 38 of Set 13 | nioro
# Processing Record 39 of Set 13 | west plains
# Processing Record 40 of Set 13 | placido de castro
# Processing Record 41 of Set 13 | huarmey
# Processing Record 42 of Set 13 | usak
# Processing Record 43 of Set 13 | anito
# Processing Record 44 of Set 13 | riachao
# Processing Record 45 of Set 13 | le port
# Processing Record 46 of Set 13 | casino
# Processing Record 47 of Set 13 | naron
# Processing Record 48 of Set 13 | tabou
# Processing Record 49 of Set 13 | ranong
# Processing Record 50 of Set 13 | oranjemund
# Processing Record 1 of Set 14 | cayenne
# Processing Record 2 of Set 14 | sergeyevka
# Processing Record 3 of Set 14 | general roca
# Processing Record 4 of Set 14 | estevan
# Processing Record 5 of Set 14 | pasaco
# Processing Record 6 of Set 14 | hwange
# Processing Record 7 of Set 14 | port augusta
# Processing Record 8 of Set 14 | sawakin
# Processing Record 9 of Set 14 | san carlos de bariloche
# Processing Record 10 of Set 14 | stanger
# Processing Record 11 of Set 14 | teahupoo
# Processing Record 12 of Set 14 | wufeng
# Processing Record 13 of Set 14 | aldan
# Processing Record 14 of Set 14 | alma
# Processing Record 15 of Set 14 | viedma
# Processing Record 16 of Set 14 | skjervoy
# Processing Record 17 of Set 14 | port blair
# Processing Record 18 of Set 14 | lucapa
# Processing Record 19 of Set 14 | joshimath
# Processing Record 20 of Set 14 | svetlaya
# Processing Record 21 of Set 14 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 22 of Set 14 | kudahuvadhoo
# Processing Record 23 of Set 14 | bednodemyanovsk
# City not found. Skipping...
# Processing Record 24 of Set 14 | trincomalee
# Processing Record 25 of Set 14 | choix
# Processing Record 26 of Set 14 | pimentel
# Processing Record 27 of Set 14 | verkhnyaya inta
# Processing Record 28 of Set 14 | padang
# Processing Record 29 of Set 14 | songjianghe
# Processing Record 30 of Set 14 | canon city
# Processing Record 31 of Set 14 | tshikapa
# Processing Record 32 of Set 14 | mayumba
# Processing Record 33 of Set 14 | wana
# Processing Record 34 of Set 14 | trelew
# Processing Record 35 of Set 14 | spirit river
# Processing Record 36 of Set 14 | azul
# Processing Record 37 of Set 14 | meulaboh
# Processing Record 38 of Set 14 | lephepe
# City not found. Skipping...
# Processing Record 39 of Set 14 | camana
# Processing Record 40 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 41 of Set 14 | praia
# Processing Record 42 of Set 14 | torbay
# Processing Record 43 of Set 14 | atyrau
# Processing Record 44 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 14 | okhotsk
# Processing Record 46 of Set 14 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 47 of Set 14 | sangueya
# Processing Record 48 of Set 14 | garmsar
# Processing Record 49 of Set 14 | vanimo
# Processing Record 50 of Set 14 | sokoni
# Processing Record 1 of Set 15 | dongying
# Processing Record 2 of Set 15 | wattegama
# Processing Record 3 of Set 15 | callaguip
# Processing Record 4 of Set 15 | upala
# Processing Record 5 of Set 15 | totness
# Processing Record 6 of Set 15 | canyon lake
# Processing Record 7 of Set 15 | iranshahr
# Processing Record 8 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 9 of Set 15 | makung
# City not found. Skipping...
# Processing Record 10 of Set 15 | harindanga
# Processing Record 11 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 12 of Set 15 | uray
# Processing Record 13 of Set 15 | opuwo
# Processing Record 14 of Set 15 | san pedro
# Processing Record 15 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 15 | sidi qasim
# City not found. Skipping...
# Processing Record 17 of Set 15 | arman
# Processing Record 18 of Set 15 | rodeo
# Processing Record 19 of Set 15 | labuan
# Processing Record 20 of Set 15 | prattville
# Processing Record 21 of Set 15 | henties bay
# Processing Record 22 of Set 15 | qurbus
# Processing Record 23 of Set 15 | vaxjo
# Processing Record 24 of Set 15 | bud
# Processing Record 25 of Set 15 | novo mesto
# Processing Record 26 of Set 15 | koumac
# Processing Record 27 of Set 15 | catamarca
# Processing Record 28 of Set 15 | nedjo
# Processing Record 29 of Set 15 | jaggayyapeta
# Processing Record 30 of Set 15 | arlit
# Processing Record 31 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 32 of Set 15 | shimoda
# Processing Record 33 of Set 15 | banjarmasin
# Processing Record 34 of Set 15 | bedesa
# Processing Record 35 of Set 15 | nova ushytsya
# Processing Record 36 of Set 15 | jumla
# Processing Record 37 of Set 15 | kuching
# Processing Record 38 of Set 15 | taguatinga
# Processing Record 39 of Set 15 | sinjar
# Processing Record 40 of Set 15 | eureka
# Processing Record 41 of Set 15 | yeniseysk
# Processing Record 42 of Set 15 | tezu
# Processing Record 43 of Set 15 | warren
# Processing Record 44 of Set 15 | sedan
# Processing Record 45 of Set 15 | hun
# Processing Record 46 of Set 15 | novoorsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Faanui      PF -16.4833 -151.7500     78.49        69          29
# 1       Plouzane      FR  48.3833   -4.6167     62.78        77           0
# 2     Deniliquin      AU -35.5333  144.9667     50.72        59           0
# 3         Castro      BR -24.7911  -50.0119     52.57        96         100
# 4      Bay-Khaak      RU  51.1667   94.5000     60.71        59         100
# 5    New Norfolk      AU -42.7826  147.0587     51.71        85         100
# 6       Naustdal      NO  61.5090    5.7168     54.12        92          75
# 7      Cape Town      ZA -33.9258   18.4232     58.10        96          75
# 8  Saint Anthony      US  45.0205  -93.2180     65.93        87           0
# 9        Samarai      PG -10.6167  150.6667     77.36        74         100
#
#    Wind Speed      Current Descritpion
# 0       20.58         scattered clouds
# 1       14.97                clear sky
# 2        7.11                clear sky
# 3        8.86          overcast clouds
# 4       10.04               light rain
# 5        2.73          overcast clouds
# 6        4.61                      fog
# 7        4.61  light intensity drizzle
# 8        5.75                clear sky
# 9       19.08          overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "/Users/dang/Documents/Bootcamp/World_weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
